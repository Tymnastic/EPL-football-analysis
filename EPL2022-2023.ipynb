# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the epl_clubs_info_2022-23.csv file into df1 DataFrame
df1 = pd.read_csv("C:/Users/ONILEIMO TIMILEHIN/Downloads/epl_clubs_info_2022-23.csv")
df1.head()
# Out:
#      club_name  abv hex_code  \
# 0      Arsenal  ARS  #EF0107
# 1  Aston Villa  AVL  #95BFE5
# 2  Bournemouth  BOU  #C91318
# 3    Brentford  BRE  #E30613
# 4     Brighton  BRI  #005DAA
#
#                                            logo_link
# 0  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4  https://a.espncdn.com/i/teamlogos/soccer/500/3...

# %%
# Read the epl_results_2022-23.csv file into df DataFrame
df = pd.read_csv("C:/Users/ONILEIMO TIMILEHIN/Downloads/epl_results_2022-23.csv")
df.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0
# 1  E0  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1
# 2  E0  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1
# 3  E0  06/08/2022  15:00           Leeds       Wolves     2     1   H     1
# 4  E0  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0
#
#    HTAG  ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     1  ...   2   2  16  11   3   5   1   2   0   0
# 1     0  ...   3   4   7   9   4   4   2   0   0   0
# 2     0  ...   3   2  18  16   5   5   3   3   0   0
# 3     1  ...   4   6  13   9   6   4   2   0   0   0
# 4     0  ...  10   0   9  14  11   1   0   3   0   0
#
# [5 rows x 24 columns]

# %%
# Get basic statistics of the df DataFrame
df.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  296.000000  296.000000  296.000000  296.000000  296.000000  296.000000
# mean     1.581081    1.155405    0.685811    0.543919   13.787162   11.216216
# std      1.414278    1.133244    0.863144    0.739741    5.639327    4.742224
# min      0.000000    0.000000    0.000000    0.000000    1.000000    1.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   14.000000   10.000000
# 75%      2.000000    2.000000    1.000000    1.000000   17.000000   14.000000
# max      9.000000    5.000000    5.000000    3.000000   33.000000   26.000000
#
#               HST         AST          HF          AF          HC          AC  \
# count  296.000000  296.000000  296.000000  296.000000  296.000000  296.000000
# mean     4.827703    3.837838   10.604730   10.905405    5.594595    4.483108
# ...

# %%
# Add 'Match_id' column with match IDs to the df DataFrame
df.insert(1, 'Match_id', ['M:{0:03d}'.format(i+1) for i in range(len(df))])

# Drop the 'Div' column from the df DataFrame
df.drop(columns=['Div'], inplace=True)
df.head()

# %%
# Check for null values in the df DataFrame
df.isnull().sum()
# Out:
# Match_id    0
# Date        0
# Time        0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# FTAG        0
# FTR         0
# HTHG        0
# HTAG        0
# HTR         0
# Referee     0
# HS          0
# AS          0
# HST         0
# AST         0
# HF          0
# AF          0
# HC          0
# AC          0
# HY          0
# AY          0
# HR          0
# AR          0
# dtype: int64

# %%
# Display information about the df DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Match_id  296 non-null    object
#  1   Date      296 non-null    object
#  2   Time      296 non-null    object
#  3   HomeTeam  296 non-null    object
#  4   AwayTeam  296 non-null    object
#  5   FTHG      296 non-null    int64
#  6   FTAG      296 non-null    int64
#  7   FTR       296 non-null    object
#  8   HTHG      296 non-null    int64
#  9   HTAG      296 non-null    int64
#  10  HTR       296 non-null    object
#  11  Referee   296 non-null    object
#  12  HS        296 non-null    int64
#  13  AS        296 non-null    int64
#  14  HST       296 non-null    int64
#  15  AST       296 non-null    int64
#  16  HF        296 non-null    int64
#  17  AF        296 non-null    int64
#  18  HC        296 non-null    int64
#  19  AC        296 non-null    int64
# ...

# %%
import datetime

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Convert the 'Time' column to datetime format and format it as '%I:%M %p'
df['Time'] = pd.to_datetime(df['Time'], format='%b:%M').dt.strftime('%I:%M %p')

df.info()
df.head()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Match_id   296 non-null    object
#  1   Date       296 non-null    datetime64[ns]
#  2   Time       296 non-null    object
#  3   HomeTeam   296 non-null    object
#  4   AwayTeam   296 non-null    object
#  5   FTHG       296 non-null    int64
#  6   FTAG       296 non-null    int64
#  7   FTR        296 non-null    object
#  8   HTHG       296 non-null    int64
#  9   HTAG       296 non-null    int64
#  10  HTR        296 non-null    object
#  11  Referee    296 non-null    object
#  12  HS         296 non-null    int64
#  13  AS         296 non-null    int64
#  14  HST        296 non-null    int64
#  15  AST        296 non-null    int64
#  16  HF         296 non-null    int64
#  17  AF         296 non-null    int64
#  18  HC         296 non-null    int64
# ...

# %%
# Rename columns in the df DataFrame
df.rename(columns={'HF': 'Home_fouls', 'AF': 'Away_fouls', 'HY': 'Home_offside', 'AY': 'Away_offside'})

# Concatenate the 'HomeTeam' and 'AwayTeam' columns into df_team Series
df_team = pd.concat([df['HomeTeam'], df['AwayTeam']])

df_team
# Out:
# 0      Crystal Palace
# 1              Fulham
# 2         Bournemouth
# 3               Leeds
# 4           Newcastle
#             ...
# 291          Brighton
# 292           Chelsea
# 293          Man City
# 294    Crystal Palace
# 295           Arsenal
# Length: 592, dtype: object

# %%
# Add a new column 'team_goal' with the sum of 'FTHG' and 'FTAG' columns
df['team_goal'] = df['FTHG'] + df['FTAG']
df['team_goal']
# Out:
# 0      2
# 1      4
# 2      2
# 3      3
# 4      2
#       ..
# 291    3
# 292    1
# 293    5
# 294    6
# 295    4
# Name: team_goal, Length: 296, dtype: int64

# %%
# Group the DataFrame by 'HomeTeam' and sum the goals scored at home
homegoal = df.groupby('HomeTeam').sum()
homegoal
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  AC  \
# HomeTeam
# Arsenal           42    18    14     6  285  108   97   51  142  173  106  46
# Aston Villa       25    19    14     9  176  160   70   52  148  163   64  84
# Bournemouth       15    19     7    12  149  226   52   71  169  154   62  92
# Brentford         29    16    16     5  172  204   72   76  134  168   69  74
# Brighton          25    14    10     8  238  112  100   42  149  158  109  38
# Chelsea           16    12     4     2  201  152   60   55  158  182   98  68
# Crystal Palace    14    19     4     7  172  193   50   70  183  197   68  71
# Everton           13    17     5     6  184  200   68   68  145  177   77  81
# Fulham            21    21     8    13  195  176   64   79  148  165   87  76
# Leeds             21    24    10    11  201  193   68   62  191  180   90  62
# Leicester         17    20    12    11  164  176   58   54  163  163   57  87
# ...

# %%
# Group the DataFrame by 'AwayTeam' and sum the goals scored away
awaygoal = df.groupby('AwayTeam').sum()
awaygoal
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  AC  \
# AwayTeam
# Arsenal           11    30     4    17  152  199   50   65  181  145   65  75
# Aston Villa       21    16    12     6  205  162   81   54  207  189   95  56
# Bournemouth       38    13    18     6  271  123   88   51  148  144  122  52
# Brentford         24    18    14     8  254  137   91   54  165  145  102  61
# Brighton          22    27     9    14  154  190   51   68  147  150   63  69
# Chelsea           19    13    12     8  170  179   71   61  192  165   74  77
# Crystal Palace    21    15     8     7  194  151   65   56  187  175   68  65
# Everton           26    10    12     4  260  135   86   41  145  161  101  56
# Fulham            19    18     6     7  208  140   74   51  145  164   81  52
# Leeds             30    18    10     7  216  169   82   52  164  166   74  72
# Leicester         32    23    13    13  260  162   87   55  148  159  101  52
# ...

# %%
# Calculate total goals by adding home goals and away goals
goals = homegoal.FTHG + awaygoal.FTAG
goals
# Out:
# HomeTeam
# Arsenal           72
# Aston Villa       41
# Bournemouth       28
# Brentford         47
# Brighton          52
# Chelsea           29
# Crystal Palace    29
# Everton           23
# Fulham            39
# Leeds             39
# Leicester         40
# Liverpool         50
# Man City          75
# Man United        44
# Newcastle         48
# Nottingham        24
# Southampton       24
# Tottenham         55
# West Ham          27
# Wolves            24
# dtype: int64

# %%
# Create a DataFrame 'total_goals' with 'Teams' and 'TotalGoals' columns, sorted by total goals in descending order
total_goals = goals.to_frame().sort_values(by=0, ascending=False).reset_index().rename(columns={'HomeTeam': 'Teams', 0: 'TotalGoals'})
total_goals
# Out:
#              Teams  TotalGoals
# 0         Man City          75
# 1          Arsenal          72
# 2        Tottenham          55
# 3         Brighton          52
# 4        Liverpool          50
# 5        Newcastle          48
# 6        Brentford          47
# 7       Man United          44
# 8      Aston Villa          41
# 9        Leicester          40
# 10           Leeds          39
# 11          Fulham          39
# 12  Crystal Palace          29
# 13         Chelsea          29
# 14     Bournemouth          28
# 15        West Ham          27
# 16      Nottingham          24
# 17     Southampton          24
# 18          Wolves          24
# 19         Everton          23

# %%
import seaborn as sns
# Plot a bar chart showing the total goals scored by each team
plt.figure(figsize=(10, 5))
plt
plt.xlabel('Total Goals')
plt.ylabel('Teams')
plt.title('TOTAL GOALS SCORED BY TEAM')
figx = sns.barplot(data=total_goals, x='TotalGoals', y='Teams')
ax = figx.axes
for p in ax.patches:
    ax.text(x=p.get_width(), y=p.get_y() + p.get_height() / 2, s=int(p.get_width()), ha="left", va="center")

# %%
# Calculate goals against by adding away goals and home goals against
GoalsAgainst = homegoal.FTAG + awaygoal.FTHG
Goals_Against = GoalsAgainst.to_frame().sort_values(by=0, ascending=True).reset_index().rename(columns={'HomeTeam': 'Team', 0: 'GoalsAgainst'})

plt.figure(figsize=(10, 5))
plt.xlabel('Goals Against')
plt.ylabel('Team')
plt.title('TOTAL GOALS SCORED AGAINST')
# Create a bar plot showing the total goals scored against each team
fig2 = sns.barplot(data=Goals_Against, x='GoalsAgainst', y='Team')
ax = fig2.axes

# Add data value labels to each bar
for p in ax.patches:
    ax.text(x=p.get_width(), y=p.get_y() + p.get_height() / 2, s=int(p.get_width()), ha="left", va="center")

# %%
# Count the number of matches officiated by each referee
df['Referee'].value_counts()

# Plot a bar chart showing the number of matches officiated by each referee
df['Referee'].value_counts().plot(kind='bar', color='blue', figsize=(10, 6))
plt.xlabel('Referee')
plt.ylabel('Matches')
plt.title('Number of Officiated Matches By Referees')
plt.show()

# %%
# Calculate the total corners for each team by summing home corners and away corners
homecorners = df.groupby('HomeTeam').sum()
awaycorners = df.groupby('AwayTeam').sum()

# Calculate the total corners for each team and create a DataFrame 'col'
col = (homecorners['HC'] + awaycorners['AC']).to_frame().sort_values(by=0, ascending=False).reset_index().rename(columns={'HomeTeam': 'Teams', 0: 'Corners'})

# Create a color palette for the bar plot
palette = sns.color_palette('cubehelix', n_colors=len(col['Teams'].unique()))

# Plot a bar chart showing the total corners for each team
fig3=sns.barplot(data=col, x='Corners', y='Teams', palette=palette)
plt.figure(figsize=(12,8 ))
ax=fig3.axes
# Add data value labels to each bar
for p in ax.patches:
    ax.text(x=p.get_width(), y=p.get_y() + p.get_height() / 2, s=int(p.get_width()), ha="left", va="center")

# %%
# Calculate the total number of offside incidents for each team
F = df.groupby('HomeTeam')['HY'].sum()
offside = df.groupby('HomeTeam')['HY'].sum() + df.groupby('AwayTeam')['AY'].sum()
offsides = offside.to_frame().sort_values(by=0, ascending=False).reset_index().rename(columns={'HomeTeam': 'Team', 0: 'Offsides'})

# Plot a bar chart showing the total number of offside incidents for each team
offsides.plot.bar(x='Team', y='Offsides', color=['r'], figsize=(10, 8))
plt.xlabel('Team')
plt.ylabel('No of Offside')
plt.title('Total offsides')
plt.show()

# %%
# match wins
def match_outcome(row):
    if row['FTR'] == 'H':
        return row['HomeTeam'] + ' Win'
    elif row['FTR'] == 'A':
        return row['AwayTeam'] + ' Win'
    else:
        return 'Draw'

# Apply the match_outcome function to each row in the DataFrame to create a new column 'Outcome'
df['Outcome'] = df.apply(match_outcome, axis=1)

teamwins=df[df['Outcome'] !='Draw'].Outcome.value_counts().to_frame().reset_index().rename(columns={'index':'Team','Outcome':'Wins'})
# Plot a bar chart to show the distribution of match outcomes
plt.figure(figsize=(8, 6))
fig4=sns.barplot(data=teamwins,x= 'Wins', y='Team')
ax=fig4.axes
# Add data value labels to each bar
for p in ax.patches:
    ax.text(x=p.get_width(), y=p.get_y() + p.get_height() / 2, s=int(p.get_width()), ha="left", va="center")

plt.axis('equal')
plt.title('Match Outcomes')
plt.show()

# %%
# Calculate the average number of goals scored per match for each team
home_goals_avg = df.groupby('HomeTeam')['FTHG'].mean()
away_goals_avg = df.groupby('AwayTeam')['FTAG'].mean()
total_goals_avg = (home_goals_avg + away_goals_avg) / 2
# Sort the average goals scored in descending order and create a DataFrame 'avg_goals'
avg_goals = total_goals_avg.to_frame().sort_values(by=0, ascending=False).reset_index().rename(columns={'HomeTeam': 'Teams', 0: 'AverageGoalsPerMatch'})
avg_goals
# Out:
#              Teams  AverageGoalsPerMatch
# 0         Man City              2.611905
# 1          Arsenal              2.400000
# 2         Brighton              1.857143
# 3        Tottenham              1.833333
# 4        Liverpool              1.752381
# 5        Newcastle              1.654762
# 6        Brentford              1.566667
# 7       Man United              1.507143
# 8      Aston Villa              1.366667
# 9           Fulham              1.342857
# 10       Leicester              1.333333
# 11           Leeds              1.300000
# 12  Crystal Palace              0.966667
# 13         Chelsea              0.966667
# 14     Bournemouth              0.933333
# 15        West Ham              0.919048
# 16     Southampton              0.800000
# 17          Wolves              0.800000
# 18      Nottingham              0.800000
# 19         Everton              0.766667

# %%
# Plot a horizontal bar chart to show the average number of goals scored per match by each team
import seaborn as sns
plt.figure(figsize=(10, 6))
fig5=sns.barplot(data=avg_goals, x='AverageGoalsPerMatch', y='Teams')
ax=fig5.axes
# Add data value labels to each bar
for p in ax.patches:
    ax.text(x=p.get_width(), y=p.get_y() + p.get_height() / 2, s=f'{p.get_width():.2f}', ha="left", va="center")

plt.xlabel('Average Goals')
plt.ylabel('Teams')

plt.title('Average Goals Scored per Match by Team')
plt.show()
